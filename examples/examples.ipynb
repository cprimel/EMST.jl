# %%
using EMST
using Plots, MLDatasets
pyplot();
# Out:
# ** (process:4999): WARNING **: 11:38:52.473: Failed to load shared library 'libpango-1.0.so.0' referenced by the typelib: /usr/lib/libpango-1.0.so.0: undefined symbol: hb_ot_layout_get_horizontal_baseline_tag_for_script

# %%
iris_features = Iris.features();
(edges, _, oldfromnew) = EMST.compute_emst(iris_features;leafSize=1);
# Out:
# --> ngroups: 150
# --> ngroups: 42
# --> ngroups: 8
# --> ngroups: 3

# %%
  scatter(iris_features[1,:],iris_features[2,:], iris_features[3,:], ms=3.0,marker=(stroke(0,:gray)))
  for zr in 1:size(edges,1)
    plot!( iris_features[1,edges[zr,:]] , iris_features[2,edges[zr,:]] , iris_features[3,edges[zr,:]],linecolor = :gray)
  end
  scatter!(legend=false)

# %%
x = Array{Float64,2}(undef, 2, 8)
    
x[1,1], x[2,1] = 0., 0.
x[1,2], x[2,2] = 0., 1.
x[1,3], x[2,3] = 1.0, 2.5
x[1,4], x[2,4] = 0.5, 3.0
x[1,5], x[2,5] = 0.25, 4.
x[1,6], x[2,6] = 4.0, 0.
x[1,7], x[2,7] = 1.0, 3.0
x[1,8], x[2,8] = 6.0, 3.0

(x_emst, _, _) = EMST.compute_emst(x;leafSize=1)
# Out:
# --> ngroups: 8
# --> ngroups: 3
# ([6 8; 2 3; … ; 3 7; 1 2], [3.605551275463989, 1.8027756377319946, 0.5, 3.905124837953327, 1.0307764064044151, 0.5, 1.0], [1, 2, 4, 5, 3, 7, 6, 8])

# %%
scatter(x[1,:],x[2,:], ms=3.0,marker=(stroke(0,:gray)))
for zr in 1:size(x_emst,1)
  plot!( x[1,x_emst[zr,:]] , x[2,x_emst[zr,:]] ,linecolor = :gray)
end
scatter!(legend=false)
